# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('input/zomato.csv')

# %%
gk=df.groupby('cuisines')

# %%
gk.first()
# Out:
#                                                                                                   url  \
# cuisines
# African, Burger                                     https://www.zomato.com/bangalore/galitos-banne...
# African, Burger, Desserts, Beverages, Fast Food     https://www.zomato.com/bangalore/galitos-white...
# American                                            https://www.zomato.com/bangalore/quiznos-sarja...
# American, Asian, Continental, North Indian, Sou...  https://www.zomato.com/bangalore/tapout-tavern...
# American, Asian, European, North Indian             https://www.zomato.com/bangalore/monkey-bar-in...
# American, BBQ                                       https://www.zomato.com/bangalore/hard-rock-caf...
# American, Bakery, Beverages, Cafe, Healthy Food...  https://www.zomato.com/bangalore/healthy-smoot...
# American, Burger, Fast Food                         https://www.zomato.com/bangalore/cravy-wings-b...
# ...

# %%
dk=df.groupby('location')

# %%
df=df.dropna(axis=0,how="any")

# %%
dk.first()
# Out:
#                                                                              url  \
# location
# BTM                            https://www.zomato.com/bangalore/sankranthi-ve...
# Banashankari                   https://www.zomato.com/bangalore/jalsa-banasha...
# Banaswadi                      https://www.zomato.com/bangalore/cafe-nibras-b...
# Bannerghatta Road              https://www.zomato.com/bangalore/deja-vu-resto...
# Basavanagudi                   https://www.zomato.com/bangalore/grand-village...
# Basaveshwara Nagar             https://www.zomato.com/bangalore/onesta-basave...
# Bellandur                      https://www.zomato.com/bangalore/kava-fairfiel...
# Bommanahalli                   https://www.zomato.com/bangalore/pizza-palace-...
# Brigade Road                   https://www.zomato.com/bangalore/kitchen-on-ta...
# Brookefield                    https://www.zomato.com/bangalore/onesta-brooke...
# ...

# %%
plt.bar(gk.head(10),dk.head(10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-cad6f2bfb7d3> in <module>()
# ----> 1 plt.bar(gk.head(10),dk.head(10))
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(*args, **kwargs)
#    2773                       mplDeprecation)
#    2774     try:
# -> 2775         ret = ax.bar(*args, **kwargs)
#    2776     finally:
#    2777         ax._hold = washold
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, *args, **kwargs)
# ...

# %%
gkk=df.groupby(['cuisines','name'])

# %%
gkk.first()
# Out:
#                                                                                                                                                      url  \
# cuisines                                           name
# African, Burger                                    Galito's                                            https://www.zomato.com/bangalore/galitos-banne...
# African, Burger, Desserts, Beverages, Fast Food    Galito's                                            https://www.zomato.com/bangalore/galitos-white...
# American                                           OvenTreats - Patisserie.Bistro                      https://www.zomato.com/bangalore/oventreats-pa...
#                                                    Uno Chicago Bar & Grill                             https://www.zomato.com/bangalore/uno-chicago-b...
# American, Asian, Continental, North Indian, Sou... Tapout Tavern                                       https://www.zomato.com/bangalore/tapout-tavern...
# ...

# %%
plt.bar(gkk.head(10),df.votes.head(10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-bf5f96f41e11> in <module>()
# ----> 1 plt.bar(gkk.head(10),df.votes.head(10))
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(*args, **kwargs)
#    2773                       mplDeprecation)
#    2774     try:
# -> 2775         ret = ax.bar(*args, **kwargs)
#    2776     finally:
#    2777         ax._hold = washold
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...

# %%
plt.bar(df.location.tail(20),df.cuisines.tail(20))

plt.legend(["this is cuisines","rest_tupe"])

# %%
n=df[df.name=="Onesta"]

# %%
n.head(5)
# Out:
#                                                     url  \
# 7     https://www.zomato.com/bangalore/onesta-banash...
# 44    https://www.zomato.com/bangalore/onesta-banash...
# 557   https://www.zomato.com/bangalore/onesta-banash...
# 909   https://www.zomato.com/bangalore/onesta-jp-nag...
# 1015  https://www.zomato.com/bangalore/onesta-jp-nag...
#
#                                                 address    name online_order  \
# 7     2469, 3rd Floor, 24th Cross, Opposite BDA Comp...  Onesta          Yes
# 44    2469, 3rd Floor, 24th Cross, Opposite BDA Comp...  Onesta          Yes
# 557   2469, 3rd Floor, 24th Cross, Opposite BDA Comp...  Onesta          Yes
# 909   Site 15, 15th Cross, 100 Feet Road, 4th Phase,...  Onesta          Yes
# 1015  Site 15, 15th Cross, 100 Feet Road, 4th Phase,...  Onesta          Yes
#
#      book_table   rate  votes                               phone  \
# 7           Yes  4.6/5   2556        080 48653961\r\n080 48655715
# ...

# %%
plt.plot(n.name.head(10),n.votes.head(10))

# %%
plt.bar(df.name.head(10),df.cuisines.head(10))
# Out:
# <BarContainer object of 10 artists>

# %%
nme=df[df.name=="Smacznego"]

# %%
nme
# Out:
#                                                      url  \
# 9      https://www.zomato.com/bangalore/smacznego-ban...
# 212    https://www.zomato.com/bangalore/smacznego-ban...
# 565    https://www.zomato.com/bangalore/smacznego-ban...
# 2517   https://www.zomato.com/bangalore/smacznego-ban...
# 2568   https://www.zomato.com/bangalore/smacznego-ban...
# 3491   https://www.zomato.com/bangalore/smacznego-ban...
# 19566  https://www.zomato.com/bangalore/smacznego-ban...
#
#                                                  address       name  \
# 9      2470, 21 Main Road, 25th Cross, Banashankari, ...  Smacznego
# 212    2470, 21 Main Road, 25th Cross, Banashankari, ...  Smacznego
# 565    2470, 21 Main Road, 25th Cross, Banashankari, ...  Smacznego
# 2517   2470, 21 Main Road, 25th Cross, Banashankari, ...  Smacznego
# 2568   2470, 21 Main Road, 25th Cross, Banashankari, ...  Smacznego
# 3491   2470, 21 Main Road, 25th Cross, Banashankari, ...  Smacznego
# ...

# %%
plt.plot(nme.location.head(20),nme.votes.head(20))
